# %%
import matplotlib.pyplot as plt
import csv
import matplotlib as mpl
import numpy as np
plt.rcParams.update({
    #"font.size": 28,
    "font.size": 16,
    "font.sans-serif": 'Arial',
    "text.usetex": True
})
cl = ["blue","orange","green","red","purple","brown","pink","grey"]

# %% [markdown]
# ### Make plots - VQE

# %%
file8p = [i.strip().split() for i in open("./data/N=8_h=0.0_J=1.0_lr=0.08_niter=500_infids_eng_dif.dat",'r').readlines()]
Infids8p = [float(i) for i in file8p[0]]
Endiffs8p = [float(i) for i in file8p[1]]
file8m = [i.strip().split() for i in open("./data/N=8_h=0.0_J=-1.0_lr=0.08_niter=500_infids_eng_dif.dat",'r').readlines()]
Infids8m = [float(i) for i in file8m[0]]
Endiffs8m = [float(i) for i in file8m[1]]
file12p = [i.strip().split() for i in open("./data/N=12_h=0.0_J=1.0_lr=0.08_niter=500_infids_eng_dif.dat",'r').readlines()]
Infids12p = [float(i) for i in file12p[0]]
Endiffs12p = [float(i) for i in file12p[1]]
file12m = [i.strip().split() for i in open("./data/N=12_h=0.0_J=-1.0_lr=0.08_niter=500_infids_eng_dif.dat",'r').readlines()]
Infids12m = [float(i) for i in file12m[0]]
Endiffs12m = [float(i) for i in file12m[1]]

# %%
file8p[0]
# Out:
# ['2.3314683517128287e-15',
#  '4.884981308350689e-15',
#  '7.66053886991358e-15',
#  '1.0547118733938987e-14',
#  '1.3433698597964394e-14']

# %%
#Infidelity plots
fig, axs = plt.subplots(1,2)
axs[0].plot(range(1,6),Infids8m, color="blue",label=r"$N=8$")
axs[0].scatter(range(1,6),Infids8m, color = "blue", s=30)
axs[0].plot(range(1,6),Infids12m, color="orange",label=r"$N=12$")
axs[0].scatter(range(1,6),Infids12m, color = "orange", s=30)
axs[1].plot(range(1,6),Endiffs8m, color="blue",label=r"$N=8$")
axs[1].scatter(range(1,6),Endiffs8m, color = "blue", s=30)
axs[1].plot(range(1,6),Endiffs12m, color="orange",label=r"$N=12$")
axs[1].scatter(range(1,6),Endiffs12m, color = "orange", s=30)
for ax in axs.flat:
    ax.set(xlabel=r"$d$",xticks=range(1,6),ylim=[1e-15,7],yscale="log")
axs[0].set_yticks([1e-15, 1e-10, 1e-5, 1e0],[r"$10^{-15}$", r"$10^{-10}$",r"$10^{-5}$",r"$10^{0}$"])
axs[1].set_yticks([1e-15, 1e-10, 1e-5, 1e0],[r"$10^{-15}$", r"$10^{-10}$",r"$10^{-5}$",r"$10^{0}$"])
axs[0].set_ylabel(r"$1-F$")
axs[1].set_ylabel(r"$\Delta$E")
# plt.plot(1:5,abs.(Infids18[1:5]), color="green",label="N=18")
# plt.scatter(1:5,abs.(Infids18[1:5]), color = :Green, s=30)
plt.figtext(0.03, 0.06,r"$(a)$")
plt.figtext(0.52, 0.06,r"$(b)$")
axs[0].legend(handlelength=1, frameon=False)
axs[1].legend(handlelength=1, frameon=False)
plt.tight_layout()
filename="../figures_data/h=0_VQE_infids&endifs"
saveplot = "{filename}.pdf".format(filename=filename)
saveplot2 = "{filename}.png".format(filename=filename)
plt.savefig(saveplot,pad_inches = 0, bbox_inches='tight')
plt.savefig(saveplot2,pad_inches = 0, bbox_inches='tight')
plt.show()

# %%
#Energy plots
plt.yscale('log')
plt.ylim(1e-15, 7)
plt.yticks([1e-15, 1e-10, 1e-5, 1e0],["$10^{-15}$", "$10^{-10}$","$10^{-5}$","$10^{0}$"])
plt.xticks(range(0,6))
plt.xlabel("d")
plt.ylabel("$\Delta$E")
plt.plot(range(1,6),Endiffs8m, color="blue",label="$N=8$")
plt.scatter(range(1,6),Endiffs8m, color = "blue", s=30)
plt.plot(range(1,6),Endiffs12m, color="orange",label="$N=12$")
plt.scatter(range(1,6),Endiffs12m, color = "orange", s=30)
# plt.plot(1:5,abs.(Infids18[1:5]), color="green",label="N=18")
# plt.scatter(1:5,abs.(Infids18[1:5]), color = :Green, s=30)
plt.figtext(0.06, 0.12,"(b)")
plt.legend(handlelength=1, frameon=False)
plt.tight_layout()
saveplot = "../figures_data/h=0_VQE_en_dif.pdf"
plt.savefig(saveplot)
plt.show()

# %% [markdown]
# ### Make plots - QFD

# %% [markdown]
# Fix n_k vary n_l

# %%
file_nk = [i.strip().split() for i in open("./data/N=8_h=0.1_J=-1.0_fix_n_k.dat",'r').readlines()]
file_nk_trot = [i.strip().split() for i in open("./data/N=8_h=0.1_J=-1.0_fix_n_k_trot_r=1.dat",'r').readlines()]
# nk0 = [float(i) for i in file_nk[0]]
# nk1 = [float(i) for i in file_nk[1]]
# nk2 = [float(i) for i in file_nk[2]]
# nk3 = [float(i) for i in file_nk[3]]
# nk4 = [float(i) for i in file_nk[4]]
# nk5 = [float(i) for i in file_nk[5]]
nk = [[float(i) for i in file_nk[j]] for j in range(6)]
nkt = [[float(i) for i in file_nk_trot[j]] for j in range(6)]

# %%
# Out:
# [0.011221595183608825,
#  2.748337459741236e-10,
#  1.9330662892170752e-11,
#  5.247864407008987e-12,
#  3.7198097708504876e-12,
#  2.480387677077483e-12]

# %%
fig, axs = plt.subplots(1,2)
for i in range(6):
    axs[0].plot(range(0,6),nk[i],color = cl[i],label=r"$nk={i}$".format(i=i))
    axs[0].scatter(range(0,6), nk[i], color = cl[i], s=30)
    axs[1].plot(range(0,6),nkt[i],color = cl[i])
    axs[1].scatter(range(0,6), nkt[i], color = cl[i], s=30)
for ax in axs.flat:
    ax.set(xlabel=r"$n_l$", ylabel=r"$\Delta$E",xticks=range(0,6),ylim=[1e-8, 1],yscale="log")
axs[0].set_yticks([1e-15, 1e-10, 1e-5, 1e0],[r"$10^{-15}$", r"$10^{-10}$",r"$10^{-5}$",r"$10^{0}$"])
axs[1].set_yticks([1e-15, 1e-10, 1e-5, 1e0],[r"$10^{-15}$", r"$10^{-10}$",r"$10^{-5}$",r"$10^{0}$"])
plt.figtext(0.03, 0.06,r"$(a)$")
plt.figtext(0.52, 0.06,r"$(b)$")
fig.legend(handlelength=1, frameon=False,loc='upper left',ncols=3,bbox_to_anchor=(0.15, 1.1))
#axs[0].legend(handlelength=1, frameon=False,loc='upper right',ncols=2,bbox_to_anchor=(1.03, 1.04))
#axs[1].legend(handlelength=1, frameon=False,ncols=2,loc='lower left',bbox_to_anchor=(-0.02, -0.05))
plt.tight_layout()
filename="../figures_data/N=8_J=-1_h=0.1_fix_n_k_exact&trot"
saveplot = "{filename}.pdf".format(filename=filename)
saveplot2 = "{filename}.png".format(filename=filename)
# plt.savefig(saveplot,pad_inches = 0, bbox_inches='tight')
# plt.savefig(saveplot2,pad_inches = 0, bbox_inches='tight')
plt.show()

# %%
#Energy plots
plt.yscale('log')
plt.ylim(1e-8, 10)
#plt.ylim(1e-8, 1)
plt.yticks([1e-15, 1e-10, 1e-5, 1e0],[r"$10^{-15}$", r"$10^{-10}$",r"$10^{-5}$",r"$10^{0}$"])
#plt.yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0],["$10^{-8}$", "$10^{-6}$","$10^{-4}$","$10^{-2}$","$10^{0}$"])
plt.xticks(range(0,6))
plt.xlabel(r"$n_l$")
plt.ylabel(r"$\Delta$E")
plt.plot(range(0,6),nk0, color=cl[0],label=r"$n_k=0$")
plt.scatter(range(0,6),nk0, color = cl[0], s=30)
plt.plot(range(0,6),nk1, color=cl[1],label=r"$n_k=1$")
plt.scatter(range(0,6),nk1, color = cl[1], s=30)
plt.plot(range(0,6),nk2, color=cl[2],label=r"$n_k=2$")
plt.scatter(range(0,6),nk2, color = cl[2], s=30)
plt.plot(range(0,6),nk3, color=cl[3],label=r"$n_k=3$")
plt.scatter(range(0,6),nk3, color = cl[3], s=30)
plt.plot(range(0,6),nk4, color=cl[4],label=r"$n_k=4$")
plt.scatter(range(0,6),nk4, color = cl[4], s=30)
plt.plot(range(0,6),nk5, color=cl[5],label=r"$n_k=5$")
plt.scatter(range(0,6),nk5, color = cl[5], s=30)
# plt.plot(range(0,5),nk3[0:5], color=cl[3],label="$n_k=3$")
# plt.scatter(range(0,5),nk3[0:5], color = cl[3], s=30)
# plt.plot(range(0,4),nk4[0:4], color=cl[4],label="$n_k=4$")
# plt.scatter(range(0,4),nk4[0:4], color = cl[4], s=30)
# plt.plot(range(0,3),nk5[0:3], color=cl[5],label="$n_k=5$")
# plt.scatter(range(0,3),nk5[0:3], color = cl[5], s=30)
plt.figtext(0.03, 0.06,r"$(a)$")
plt.legend(handlelength=1, frameon=False,loc='upper right',ncols=2,bbox_to_anchor=(1.03, 1.04))
#plt.legend(handlelength=1, frameon=False,ncols=2,loc='lower left',bbox_to_anchor=(-0.02, -0.05))
plt.tight_layout()
filename="../figures_data/N=8_J=-1_h=0.1_fix_n_k"
saveplot = "{filename}.pdf".format(filename=filename)
saveplot2 = "{filename}.png".format(filename=filename)
plt.savefig(saveplot)
plt.savefig(saveplot2)
# plt.savefig(saveplot,pad_inches = 0, bbox_inches='tight')
# plt.savefig(saveplot2,pad_inches = 0, bbox_inches='tight')
plt.show()

# %% [markdown]
# Fix h increase # basis states

# %%
file_h = [i.strip().split() for i in open("./data/N=8_range_h_J=-1.0_inc_basis_no.dat",'r').readlines()]
h1 = [float(i) for i in file_h[0]]
h2 = [float(i) for i in file_h[1]]
h3 = [float(i) for i in file_h[2]]
h4 = [float(i) for i in file_h[3]]
h5 = [float(i) for i in file_h[4]]

# %%
nk_nl=[[0,0],[1,0],[2,0],[1,1],[4,0],[2,1],[6,0],[3,1],[2,2],[4,1],[10,0],[3,2],[12,0],[6,1],[4,2],[3,3],[16,0],[5,2]]
n_basis = [2*(i[0]+1)*(i[1]+1)-1 for i in nk_nl]

# %%
#Energy plots
plt.yscale('log')
plt.ylim(1e-15, 10)
plt.yticks([1e-15, 1e-10, 1e-5, 1e0],["$10^{-15}$", "$10^{-10}$","$10^{-5}$","$10^{0}$"])
#plt.yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0],["$10^{-8}$","$10^{-6}$","$10^{-4}$","$10^{-2}$","$10^{0}$"])
plt.xticks(range(0,40,5))
plt.xlabel("Number of basis states")
plt.ylabel("$\Delta$E")
plt.plot(n_basis,h1, color=cl[0],label="$h=0.1$")
plt.plot(n_basis,h2, color=cl[1],label="$h=0.2$")
plt.plot(n_basis,h3, color=cl[2],label="$h=0.3$")
plt.plot(n_basis,h4, color=cl[3],label="$h=0.4$")
plt.plot(n_basis,h5, color=cl[4],label="$h=0.5$")
# plt.plot(n_basis,h1, color=cl[0],label="$h=0.1$")
# plt.plot(n_basis,h3, color=cl[1],label="$h=0.3$")
# plt.plot(n_basis,h5, color=cl[2],label="$h=0.5$")
plt.legend(handlelength=1, frameon=False)
plt.tight_layout()
#saveplot = "../figures_data/N=12_J=-1_range_h_inc_basis_no.pdf"
#plt.savefig(saveplot)
plt.show()

# %%
file8m = [i.strip().split() for i in open("./data/N=8_range_h_J=-1.0_inc_basis_no.dat",'r').readlines()]
file12m = [i.strip().split() for i in open("./data/N=12_range_h_J=-1.0_inc_basis_no.dat",'r').readlines()]
file8p = [i.strip().split() for i in open("./data/N=8_range_h_J=1.0_inc_basis_no.dat",'r').readlines()]
file12p = [i.strip().split() for i in open("./data/N=12_range_h_J=1.0_inc_basis_no.dat",'r').readlines()]
# h8m = [float(i) for i in file8m[0]]
# h12m = [float(i) for i in file12m[0]]
# h8p = [float(i) for i in file8p[0]]
# h12p = [float(i) for i in file12p[0]]
filem = [file8m,file8p,file12p,file12m]
hm=[[float(i) for i in file[0]] for file in filem]
file_trot = [i.strip().split() for i in open("./data/N=8_12_h=0.1_J=pm1_range_trot_steps.dat",'r').readlines()]
htrot = [[float(i) for i in file_trot[j]] for j in range(4)]

# %%
labels[1]
l3
# Out:
# '${\\sqrt{b/a}}$'

# %%
fig, axs = plt.subplots(1,2)
#labels=["$N=8,J=\plus1$","$N=8,J=\minus1$","$N=12,J=\plus1$","$N=12,J=\minus1$"]
labels=[r"${N=8,J=+1}$",r"${N=8,J=-1}$",r"${N=12,J=+1}$",r"${N=12,J=-1}$"]
for i in range(4):
    axs[0].plot(n_basis,hm[i],color=cl[i],label=f"{labels[i]}")
    axs[0].scatter(n_basis,hm[i],color=cl[i])
    axs[1].plot(range(1,11),htrot[i],color=cl[i])
    axs[1].scatter(range(1,11),htrot[i],color=cl[i])
for ax in axs.flat:
    ax.set(ylabel=r"$\Delta$E",yscale="log")
axs[0].set_yticks([1e-15, 1e-10, 1e-5, 1e0],[r"$10^{-15}$", r"$10^{-10}$",r"$10^{-5}$",r"$10^{0}$"])
axs[1].set_yticks([1e-15, 1e-10, 1e-5, 1e0],[r"$10^{-15}$", r"$10^{-10}$",r"$10^{-5}$",r"$10^{0}$"])
axs[0].set(xlabel=r"$n_\phi$",xticks=range(0,40,10))
axs[1].set(xlabel=r"$r$",xticks=range(0,12,2))
#axs[1].set(xlabel=f"Test: {l3}")
plt.figtext(0.03, 0.06,r"$(a)$")
plt.figtext(0.52, 0.06,r"$(b)$")
fig.legend(handlelength=1, frameon=False,loc='upper left',ncols=2,bbox_to_anchor=(0.15, 1.1))
# axs[0].legend(handlelength=1, frameon=False)
# axs[1].legend(handlelength=1, frameon=False)
plt.tight_layout()
filename="../figures_data/N=8_12_J=pm1_h=0.1_inc_basis_no_&_trot_steps"
saveplot = "{filename}.pdf".format(filename=filename)
saveplot2 = "{filename}.png".format(filename=filename)
plt.savefig(saveplot,pad_inches = 0, bbox_inches='tight')
plt.savefig(saveplot2,pad_inches = 0, bbox_inches='tight')
plt.show()

# %%
# Out:
# '$N=8,J=\\minus1$'

# %%
#Energy plots
plt.yscale('log')
plt.ylim(1e-17, 10)
plt.yticks([1e-15, 1e-10, 1e-5, 1e0],["$10^{-15}$", "$10^{-10}$","$10^{-5}$","$10^{0}$"])
plt.xticks(range(0,40,5))
plt.xlabel("Number of basis states")
plt.ylabel("$\Delta$E")
plt.plot(n_basis,h8p, color=cl[0],label="$N=8,J=\plus1$")
plt.plot(n_basis,h8m, color=cl[1],label="$N=8,J=\minus1$")
plt.plot(n_basis,h12p, color=cl[2],label="$N=12,J=\plus1$")
plt.plot(n_basis,h12m, color=cl[3],label="$N=12,J=\minus1$")
plt.legend(handlelength=1, frameon=False,ncols=2)
plt.tight_layout()
saveplot = "../figures_data/N=8_12_J=pm1_h=0.1_inc_basis_no.pdf"
plt.savefig(saveplot)
plt.show()

# %%
#trotterization - fix n_k = n_l = 3, increase r
file_trot = [i.strip().split() for i in open("./data/N=8_12_h=0.1_J=pm1_range_trot_steps.dat",'r').readlines()]
trot8p = [float(i) for i in file_trot[0]]
trot8m = [float(i) for i in file_trot[1]]
trot12p = [float(i) for i in file_trot[2]]
trot12m = [float(i) for i in file_trot[3]]

# %%
trot12p
# Out:
# [0.0038422111857303407,
#  0.0033742362921202603,
#  0.0023977055543023965,
#  0.0014716416173572978,
#  0.0009107277784345116,
#  0.0005929064040751065,
#  0.0003994078968058845,
#  0.00027872369733870293,
#  0.00020438024254224152,
#  0.00015854138507650326]

# %%
#Energy plots
plt.yscale('log')
plt.ylim(1e-15, 1)
plt.yticks([1e-15, 1e-10, 1e-5, 1e0],["$10^{-15}$", "$10^{-10}$","$10^{-5}$","$10^{0}$"])
plt.xticks(range(1,11))
plt.xlabel("$r$")
plt.ylabel("$\Delta$E")
plt.plot(range(1,11),trot8p, color=cl[0],label="$N=8,J=\plus1$")
plt.scatter(range(1,11),trot8p, color = cl[0], s=30)
plt.plot(range(1,11),trot8m, color=cl[1],label="$N=8,J=\minus1$")
plt.scatter(range(1,11),trot8m, color = cl[1], s=30)
plt.plot(range(1,11),trot12p, color=cl[2],label="$N=12,J=\plus1$")
plt.scatter(range(1,11),trot12p, color = cl[2], s=30)
plt.plot(range(1,11),trot12m, color=cl[3],label="$N=12,J=\minus1$")
plt.scatter(range(1,11),trot12m, color = cl[3], s=30)
plt.legend(handlelength=1, frameon=False,ncols=2)
plt.tight_layout()
saveplot = "../figures_data/N=8_12_J=pm1_h=0.1_n_k=n_l=3_increase_r.pdf"
plt.savefig(saveplot)
plt.show()

# %% [markdown]
# # Green's function plots

# %%
#GF - fix n_k = n_l = 3, r = 5
file_GF = [i.strip().split() for i in open("./data/N=8_h=0.1_n_l=3_n_k=3_r=5_J=-1.0_G_11^3.dat",'r').readlines()]
file_SF = [i.strip().split() for i in open("./data/N=8_h=0.1_n_l=3_n_k=3_r=5_J=-1.0_G_12^3.dat",'r').readlines()]

gfe_r = [float(i) for i in file_GF[0]]
gfe_i = [float(i) for i in file_GF[1]]
gfc_r = [float(i) for i in file_GF[2]]
gfc_i = [float(i) for i in file_GF[3]]
gft_r = [float(i) for i in file_GF[4]]
gft_i = [float(i) for i in file_GF[5]]

sfe_r = [float(i) for i in file_SF[0]]
sfe_i = [float(i) for i in file_SF[1]]
sfc_r = [float(i) for i in file_SF[2]]
sfc_i = [float(i) for i in file_SF[3]]
sft_r = [float(i) for i in file_SF[4]]
sft_i = [float(i) for i in file_SF[5]]

# %%
#GF and DOS plots
fig, axs = plt.subplots(2,2)
omega = np.arange(0,10.1,0.1)
DOS_e = [i*-1/np.pi for i in gfe_i]
DOS_c = [i*-1/np.pi for i in gfc_i]
DOS_t = [i*-1/np.pi for i in gft_i]
SF_e = [i*-1/np.pi for i in sfe_i]
SF_c = [i*-1/np.pi for i in sfc_i]
SF_t = [i*-1/np.pi for i in sft_i]
axs[0][0].plot(omega,gfe_r, color=cl[0],label="Exact")
axs[0][0].plot(omega,gfc_r, "--", color=cl[1],label="QSE - exact evolution")
axs[0][0].plot(omega,gft_r, ":", color=cl[2],label="QSE - trotterized")
axs[0][1].plot(omega,DOS_e, color=cl[0])
axs[0][1].plot(omega,DOS_c, "--", color=cl[1])
axs[0][1].plot(omega,DOS_t, ":", color=cl[2])
for ax in axs.flat:
    ax.set(xlabel=r"$\omega$",xticks=range(0,12,2))
axs[0][0].set(ylabel=r"$Re[G_{11}(\omega+i\delta)]$")
axs[0][1].set(ylabel=r"$DOS_{11}(\omega)$")

axs[1][0].plot(omega,sfe_r, color=cl[0])
axs[1][0].plot(omega,sfc_r, "--", color=cl[1])
axs[1][0].plot(omega,sft_r, ":", color=cl[2])
axs[1][1].plot(omega,SF_e, color=cl[0])
axs[1][1].plot(omega,SF_c, "--", color=cl[1])
axs[1][1].plot(omega,SF_t, ":", color=cl[2])
axs[1][0].set(ylabel=r"$Re[G_{12}(\omega+i\delta)]$")
axs[1][1].set(ylabel=r"$SF_{12}(\omega)$")
plt.figtext(0.03, 0.56,r"$(a)$")
plt.figtext(0.52, 0.56,r"$(b)$")
plt.figtext(0.03, 0.06,r"$(c)$")
plt.figtext(0.52, 0.06,r"$(d)$")
fig.legend(handlelength=1, frameon=False,loc='upper left',ncols=2,bbox_to_anchor=(0.15, 1.1))
# axs[0].legend(handlelength=1, frameon=False)
# axs[1].legend(handlelength=1, frameon=False)
plt.tight_layout()
filename="../figures_data/N=8_h=0.1_n_l=3_n_k=3_r=5_J=-1.0_G_11^3_DOS_11^3_G_12^3_DOS_12^3"
saveplot = "{filename}.pdf".format(filename=filename)
saveplot2 = "{filename}.png".format(filename=filename)
plt.savefig(saveplot,pad_inches = 0, bbox_inches='tight')
plt.savefig(saveplot2,pad_inches = 0, bbox_inches='tight')
plt.show()

# %%
#GF and DOS plots
fig, axs = plt.subplots(1,2)
omega = np.arange(0,10.1,0.1)
DOS_e = [i*-1/np.pi for i in gfe_i]
DOS_c = [i*-1/np.pi for i in gfc_i]
DOS_t = [i*-1/np.pi for i in gft_i]
axs[0].plot(omega,gfe_r, color=cl[0],label="Exact")
axs[0].plot(omega,gfc_r, "--", color=cl[1],label="QSE - exact evolution")
axs[0].plot(omega,gft_r, ":", color=cl[2],label="QSE - trotterized")
axs[1].plot(omega,DOS_e, color=cl[0])
axs[1].plot(omega,DOS_c, "--", color=cl[1])
axs[1].plot(omega,DOS_t, ":", color=cl[2])
for ax in axs.flat:
    ax.set(xlabel=r"$\omega$",xticks=range(0,12,2))
axs[0].set(ylabel=r"$Re[G(\omega+i\delta)]$")
axs[1].set(ylabel=r"$DOS(\omega)$")
plt.figtext(0.03, 0.06,r"$(a)$")
plt.figtext(0.52, 0.06,r"$(b)$")
fig.legend(handlelength=1, frameon=False,loc='upper left',ncols=2,bbox_to_anchor=(0.15, 1.1))
# axs[0].legend(handlelength=1, frameon=False)
# axs[1].legend(handlelength=1, frameon=False)
plt.tight_layout()
filename="../figures_data/N=8_h=0.1_n_l=3_n_k=3_r=5_J=-1.0_G_11^3_DOS_11^3"
saveplot = "{filename}.pdf".format(filename=filename)
saveplot2 = "{filename}.png".format(filename=filename)
#plt.savefig(saveplot,pad_inches = 0, bbox_inches='tight')
#plt.savefig(saveplot2,pad_inches = 0, bbox_inches='tight')
plt.show()

# %%
#Energy plots
omega = np.arange(0,10.1,0.1)
#plt.yticks([1e-15, 1e-10, 1e-5, 1e0],["$10^{-15}$", "$10^{-10}$","$10^{-5}$","$10^{0}$"])
#plt.xticks(range(1,11))
plt.xlabel("$\omega$")
plt.ylabel("$Re[G(ω+i\delta)]$")
plt.plot(omega,gfe_r, color=cl[0],label="Exact")
plt.plot(omega,gfc_r, "--", color=cl[1],label="QSE - exact evolution")
plt.plot(omega,gft_r, ":", color=cl[2],label="QSE - trotterized")
plt.legend(handlelength=1, frameon=False,loc='upper left',bbox_to_anchor=(-0.02, 1))
plt.tight_layout()
plt.figtext(0.05, 0.07,"(a)")
saveplot = "../figures_data/N=8_h=0.1_n_l=3_n_k=3_r=5_J=-1.0_G_12^3.pdf"
plt.savefig(saveplot)
plt.show()

# %%
DOS_e = [i*-1/np.pi for i in gfe_i]
DOS_c = [i*-1/np.pi for i in gfc_i]
DOS_t = [i*-1/np.pi for i in gft_i]
plt.xlabel("$\omega$")
plt.ylabel("DOS($\omega$)")
plt.plot(omega,DOS_e, color=cl[0],label="Exact")
plt.plot(omega,DOS_c, "--", color=cl[1],label="QSE - exact evolution")
plt.plot(omega,DOS_t, ":", color=cl[2],label="QSE - trotterized")
plt.legend(handlelength=1, frameon=False, loc='upper left',bbox_to_anchor=(-0.02, 1))
plt.tight_layout()
plt.figtext(0.05, 0.07,"(b)")
saveplot = "../figures_data/N=8_h=0.1_n_l=3_n_k=3_r=5_J=-1.0_DOS_12^3.pdf"
plt.savefig(saveplot)
plt.show()

# %%
# file_DSF = [i.strip().split() for i in open("./data/N=8_J=-1.0_DSF_exact_v2.dat",'r').readlines()]
# file_DSF_QFD = [i.strip().split() for i in open("./data/N=8_J=-1.0_n_l=3_n_k=3_DSF_QFD_v2.dat",'r').readlines()]
file_DSF = [i.strip().split() for i in open("./data/N=8_J=-1.0_DSF_exact_omega=0.1.dat",'r').readlines()]
file_DSF_QFD = [i.strip().split() for i in open("./data/N=8_J=-1.0_n_l=3_n_k=3_DSF_QFD_omega=0.1.dat",'r').readlines()]
Gf_mat = [abs(float(i)) for i in file_DSF[0]]
Gf_mat = np.reshape(Gf_mat,(21,26)).T
Gf_mat_q = [abs(float(i)) for i in file_DSF_QFD[0]]
Gf_mat_q = np.reshape(Gf_mat_q,(21,26)).T
# Gf_mat=[[] for _ in range(26)]
# for j in range(26):
#     Gf_mat[j] = [abs(float(i)) for i in file_DSF[j]]

# %%
nm=max([max(Gf_mat[i]) for i in range(26)])
a = [[i/nm for i in j] for j in Gf_mat]
nm2=max([max(Gf_mat_q[i]) for i in range(26)])
a2 = [[i/nm2 for i in j] for j in Gf_mat_q]

# %%
#GF and DOS plots
fig, axs = plt.subplots(1,2)
im = axs[0].imshow(a,vmin=0, vmax=1, cmap="seismic", interpolation="gaussian", aspect = "auto",origin="lower",extent=(-0.00001,0.200001,-0.00001,0.500001))
im = axs[1].imshow(a2,vmin=0, vmax=1, cmap="seismic", interpolation="gaussian", aspect = "auto",origin="lower",extent=(-0.00001,0.200001,-0.00001,0.500001))
for ax in axs.flat:
    ax.set(xlabel=r"$h/|J|$",ylabel=r"$\omega/|J|$")
plt.figtext(0.03, 0.06,r"$(a)$")
plt.figtext(0.52, 0.06,r"$(b)$")
plt.tight_layout()
fig.colorbar(im,ax=axs.ravel().tolist())
filename="../figures_data/N=8_J=1.0_DSF_exact_QFD"
saveplot = "{filename}.pdf".format(filename=filename)
saveplot2 = "{filename}.png".format(filename=filename)
#plt.savefig(saveplot,pad_inches = 0, bbox_inches='tight')
#plt.savefig(saveplot2,pad_inches = 0, bbox_inches='tight')
plt.show()

# %%
plt.imshow(a,vmin=0, vmax=1, cmap="seismic", aspect = "auto",origin="lower",extent=(-0.00001,0.200001,-0.00001,0.500001))
#plt.contourf(a,vmin=0, vmax=1, cmap="seismic",origin="lower",extent=(-0.00001,0.200001,-0.00001,0.500001))
plt.xlabel("$h/|J|$")
plt.ylabel("$\omega/|J|$")
plt.colorbar()
plt.tight_layout()
plt.figtext(0.05, 0.07,"(a)")
saveplot = "../figures_data/N=8_J=-1.0_DSF_exact.pdf"
#saveplot = "../figures_data/N=8_J=-1.0_n_l=3_n_k=3_DSF_QFD.pdf"
# plt.savefig(saveplot)
plt.show()
